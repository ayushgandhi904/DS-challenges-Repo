# %% [markdown]
# ### Q-3 Write a program, which would download the data from the provided link, and then read the data and convert that into properly structured data and return it in Excel format
#
# Link : https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json

# %%
import json, requests
import pandas as pd

# %%
def file_convert(link, excel_file):
    
    #Data downloading
    response = requests.get(link)
    data = response.json()
    
    #converting into txt format
    txt = []
    for i in data["pokemon"]:
        pokemon = {
            "num" : i["num"],
            'Name': i['name'],
            'Type': ', '.join(i['type']),
            'Height': i['height'],
            'Weight': i['weight'],
            "Candy" : i["candy"],
            'Weaknesses': ', '.join(i['weaknesses']), 
            "Spawn_rate" : i["spawn_chance"],
            "Multipliers" : i["multipliers"],
            "Spawntime" : i["spawn_time"]
            
            #considering few of features only
        }
        txt.append(pokemon)
        
    #Converting data into dataframe
    df = pd.DataFrame(txt)
    #Into excel
    df.to_excel(excel_file, index = False)
    return f"File has been downloaded"

# %%
link = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"
file = "pokemon.xlsx"

# %%
file_convert(link, file)
# Out:
# 'File has been downloaded'

# %%
pd.read_excel("pokemon.xlsx")
# Out:
#      num        Name            Type  Height    Weight             Candy  \
# 0      1   Bulbasaur   Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy
# 1      2     Ivysaur   Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy
# 2      3    Venusaur   Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy
# 3      4  Charmander            Fire  0.61 m    8.5 kg  Charmander Candy
# 4      5  Charmeleon            Fire  1.09 m   19.0 kg  Charmander Candy
# ..   ...         ...             ...     ...       ...               ...
# 146  147     Dratini          Dragon  1.80 m    3.3 kg     Dratini Candy
# 147  148   Dragonair          Dragon  3.99 m   16.5 kg     Dratini Candy
# 148  149   Dragonite  Dragon, Flying  2.21 m  210.0 kg     Dratini Candy
# 149  150      Mewtwo         Psychic  2.01 m  122.0 kg              None
# 150  151         Mew         Psychic  0.41 m    4.0 kg              None
#
#                      Weaknesses  Spawn_rate   Multipliers Spawntime
# 0    Fire, Ice, Flying, Psychic      0.6900        [1.58]     20:00
# 1    Fire, Ice, Flying, Psychic      0.0420    [1.2, 1.6]     07:00
# 2    Fire, Ice, Flying, Psychic      0.0170           NaN     11:30
# 3           Water, Ground, Rock      0.2530        [1.65]     08:45
# 4           Water, Ground, Rock      0.0120        [1.79]     19:00
# ..                          ...         ...           ...       ...
# 146          Ice, Dragon, Fairy      0.3000  [1.83, 1.84]     06:41
# 147          Ice, Dragon, Fairy      0.0200        [2.05]     11:57
# 148    Ice, Rock, Dragon, Fairy      0.0011           NaN     23:38
# 149            Bug, Ghost, Dark      0.0000           NaN       NaN
# 150            Bug, Ghost, Dark      0.0000           NaN       NaN
#
# [151 rows x 10 columns]
